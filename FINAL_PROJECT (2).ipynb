# %% [markdown]
# # **A SIMPLE DATA APPLICATION WITH MACHINE LEARNING MODEL**

# %%
import pandas as pd

# %%
df=pd.read_csv('/student_depression_dataset.csv')

# %% [markdown]
# **Loading the dataset named "students performance"**

# %%
df.head()
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
# 3            0.0  5.59                 2.0               0.0
# 4            0.0  8.13                 3.0               0.0
#
#         Sleep Duration Dietary Habits   Degree  \
# 0          '5-6 hours'        Healthy  B.Pharm
# 1          '5-6 hours'       Moderate      BSc
# 2  'Less than 5 hours'        Healthy       BA
# ...

# %% [markdown]
# **This method is useful to show the first 5 rows of the dataset.**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27901 non-null  int64
#  1   Gender                                 27901 non-null  object
#  2   Age                                    27901 non-null  float64
#  3   City                                   27901 non-null  object
#  4   Profession                             27901 non-null  object
#  5   Academic Pressure                      27901 non-null  float64
#  6   Work Pressure                          27901 non-null  float64
#  7   CGPA                                   27901 non-null  float64
#  8   Study Satisfaction                     27901 non-null  float64
#  9   Job Satisfaction                       27901 non-null  float64
# ...

# %% [markdown]
# **It provides the overview of the dataframe that include index range, number of entries, non-null counts, data types and memory usage.**

# %%
df.shape
# Out:
# (27901, 18)

# %% [markdown]
# **It provides the number of rows and columns in the given dataset**

# %%
df.describe()
# Out:
#                   id           Age  Academic Pressure  Work Pressure  \
# count   27901.000000  27901.000000       27901.000000   27901.000000
# mean    70442.149421     25.822300           3.141214       0.000430
# std     40641.175216      4.905687           1.381465       0.043992
# min         2.000000     18.000000           0.000000       0.000000
# 25%     35039.000000     21.000000           2.000000       0.000000
# 50%     70684.000000     25.000000           3.000000       0.000000
# 75%    105818.000000     30.000000           4.000000       0.000000
# max    140699.000000     59.000000           5.000000       5.000000
#
#                CGPA  Study Satisfaction  Job Satisfaction  Work/Study Hours  \
# count  27901.000000        27901.000000      27901.000000      27901.000000
# mean       7.656104            2.943837          0.000681          7.156984
# std        1.470707            1.361148          0.044394          3.707642
# ...

# %% [markdown]
# **It generates the statistics for numerical columns that includes count, mean, standard deviation, minimum value, maximum value, 25%, 50%, 25% quartiles.**

# %%
df.isnull().sum()
# Out:
# id                                       0
# Gender                                   0
# Age                                      0
# City                                     0
# Profession                               0
# Academic Pressure                        0
# Work Pressure                            0
# CGPA                                     0
# Study Satisfaction                       0
# Job Satisfaction                         0
# Sleep Duration                           0
# Dietary Habits                           0
# Degree                                   0
# Have you ever had suicidal thoughts ?    0
# Work/Study Hours                         0
# Financial Stress                         0
# Family History of Mental Illness         0
# Depression                               0
# dtype: int64

# %% [markdown]
# **It provides the number of null values in each column of the dataframe
# **

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# *  It is used to remove the duplicate rows in the dataframe
# *  Here "inplace=True" is used to replace the original df instead of assigning it in the another variable.

# %%
df.encoded=pd.get_dummies(df,drop_first=True)
# Out:
# <ipython-input-20-4530b2c9ad3d>:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.encoded=pd.get_dummies(df,drop_first=True)

# %% [markdown]
# **It converts all the categorical columns into numerical columns.**

# %%
df[['Age', 'Academic Pressure', 'Work Pressure', 'Study Satisfaction', 'Depression']].mean(axis=1)
# Out:
# 0        8.2
# 1        6.2
# 2        7.8
# 3        6.8
# 4        6.4
#         ...
# 27896    7.4
# 27897    6.4
# 27898    7.6
# 27899    5.2
# 27900    6.6
# Length: 27901, dtype: float64

# %% [markdown]
# **This groups the dataframe by age and calculate it average of academic pressure ,work pressure and job statisfication.**

# %%
df.groupby('Age')[['CGPA','Job Satisfaction','Work/Study Hours']].mean()
# Out:
#           CGPA  Job Satisfaction  Work/Study Hours
# Age
# 18.0  7.551720          0.003151          7.319471
# 19.0  7.662917          0.000000          7.274359
# 20.0  7.613572          0.000894          7.236924
# 21.0  7.680349          0.000579          7.462920
# 22.0  7.526371          0.000000          6.979310
# 23.0  7.683191          0.000000          7.303951
# 24.0  7.730930          0.000886          7.231621
# 25.0  7.765353          0.001121          7.250000
# 26.0  7.724130          0.000000          7.141991
# 27.0  7.537223          0.000000          7.160739
# 28.0  7.620155          0.000000          7.157525
# 29.0  7.746138          0.001538          7.062564
# 30.0  7.735249          0.000000          6.867249
# 31.0  7.672698          0.000000          7.014015
# 32.0  7.644493          0.000000          7.067353
# 33.0  7.568051          0.000000          7.049128
# 34.0  7.680395          0.000000          6.872616
# ...

# %% [markdown]
# **This groups the dataframe by parental level of education and calculate it average of age,cgpa and work\study hour.**

# %%
df.value_counts()
# Out:
# id      Gender  Age   City           Profession  Academic Pressure  Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  Sleep Duration       Dietary Habits  Degree      Have you ever had suicidal thoughts ?  Work/Study Hours  Financial Stress  Family History of Mental Illness  Depression
# 140699  Male    27.0  Patna          Student     4.0                0.0            9.24  1.0                 0.0               'Less than 5 hours'  Healthy         BCA         Yes                                    2.0               3.0               Yes                               1             1
# 2       Male    33.0  Visakhapatnam  Student     5.0                0.0            8.97  2.0                 0.0               '5-6 hours'          Healthy         B.Pharm     Yes                                    3.0               1.0               No                                1             1
# ...

# %% [markdown]
# **This method provides the unique values count of the dataframe.**

# %%
df.columns.unique()
# Out:
# Index(['id', 'Gender', 'Age', 'City', 'Profession', 'Academic Pressure',
#        'Work Pressure', 'CGPA', 'Study Satisfaction', 'Job Satisfaction',
#        'Sleep Duration', 'Dietary Habits', 'Degree',
#        'Have you ever had suicidal thoughts ?', 'Work/Study Hours',
#        'Financial Stress', 'Family History of Mental Illness', 'Depression'],
#       dtype='object')

# %% [markdown]
# **It returns all unique column names of the dataframe.**

# %%
df['Age'].unique()
# Out:
# array([33., 24., 31., 28., 25., 29., 30., 27., 19., 20., 23., 18., 21.,
#        22., 34., 32., 26., 39., 35., 42., 36., 58., 49., 38., 51., 44.,
#        43., 46., 59., 54., 48., 56., 37., 41.])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.histplot(df['Age'],bins=20,kde=True,color='red')
plt.title("Distribution of Age")
plt.xlabel("Age")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
sns.countplot(x='Study Satisfaction',data=df, palette='Set2')
plt.title("Ditribution of Study Satisfaction")
plt.xlabel("Study Satisfaction")
plt.ylabel("Frequency")
plt.show()
# Out:
# <ipython-input-33-ec02dc492e3c>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Study Satisfaction',data=df, palette='Set2')

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='Age',y='Study Satisfaction',data=df, palette='Set2')
plt.title("Study Satisfaction by Age")
plt.xticks(rotation=45)
plt.xlabel("Age")
plt.ylabel("Study Satisfaction")
plt.show()
# Out:
# <ipython-input-37-5385bfb0d19d>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Age',y='Study Satisfaction',data=df, palette='Set2')

# %% [markdown]
# *   It visualizes the distribution of study statisfication for each Age.
# *   It shows median, quartiles and outliers.

# %%
Q1=df['Depression'].quantile(0.25)
Q2=df['Depression'].median()
Q3=df['Depression'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
outliers=df[(df['Depression']<lower_bound) | (df['Depression']>upper_bound)]
print("Lower Bound:",lower_bound)
print("Upper Bound:",upper_bound)
print("Outliers:")
print(outliers)
outliers_removed = df[(df['Depression'] >= lower_bound) & (df['Depression'] <= upper_bound)]
plt.figure(figsize=(8, 5))
sns.histplot(outliers_removed['Depression'], bins=15, kde=True, color='darkblue')
plt.axvline(lower_bound, color='red', linestyle='--', label='Lower Bound')
plt.axvline(upper_bound, color='green', linestyle='--', label='Upper Bound')
plt.title('Depression Distribution (Outliers Removed)')
plt.xlabel('Depression')
plt.ylabel('Frequency')
plt.legend()
plt.show()
# Out:
# Lower Bound: -1.5
# Upper Bound: 2.5
# Outliers:
# Empty DataFrame
# Columns: [id, Gender, Age, City, Profession, Academic Pressure, Work Pressure, CGPA, Study Satisfaction, Job Satisfaction, Sleep Duration, Dietary Habits, Degree, Have you ever had suicidal thoughts ?, Work/Study Hours, Financial Stress, Family History of Mental Illness, Depression]
# Index: []

# %% [markdown]
# # **MODEL DEVELOPMENT**

# %%
df_encoded = pd.get_dummies(df, drop_first=True)

x = df_encoded.drop(columns=['CGPA'])
y = df_encoded['Academic Pressure']

# %% [markdown]
# **In this, x variable contains the input features by dropping the target values. y variable contains only the target value which 'writing score'**

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# **
#
# *   Here train_test_split() is a function from sklearn that splits the dataset into the following:
#
#
# 1.  **x_train:** It contains 80 % of the input data to train the model.
# 2.   **x_test:** It contains 20 % of the input data to test the model.
# 3. **y_train:** It contains 80 % of the target variable.
# 4.   **y_test:** It contains 20 % of the target variable.
#
# **

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# **Here, Depression is the continuous numeric value so we use linear regression for this dataframe
# **

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %% [markdown]
# **Predict the test data.**

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error,r2_score
import numpy as np

mae=mean_absolute_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
rmse=np.sqrt(mse)
r2=r2_score(y_test,y_pred)

# %% [markdown]
# **RESULT PRESENTATION**

# %% [markdown]
# **It shows the Mean Absolute Error,Mean Squared Error,Root Mean Squared Error,R-squared**

# %%
print("Mean Absolute Error:",mae)
print("Mean Squared Error:",mse)
print("Root Mean Squared Error:",rmse)
print("R-squared:",r2)
# Out:
# Mean Absolute Error: 3.5659495444481414e-11
# Mean Squared Error: 1.9839838290705046e-21
# Root Mean Squared Error: 4.454193337822803e-11
# R-squared: 1.0

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test,y_test,color='red')
plt.scatter(y_test,y_pred,color='skyblue')
plt.plot([y.min(),y.max()],[y.min(),y.max()],'--b',label='perfect prediction line')
plt.xlabel("Actual Depression")
plt.ylabel("Predicted Depression")
plt.title("Actual vs Predicted Depression")
plt.show()

# %% [markdown]
# **It shows that how well the model predicted the Depression as same as the Actual Depression**
